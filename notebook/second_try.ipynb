# %%
import numpy as np
import pandas as pd 
import numpy.random as rn
from tqdm import tqdm_notebook as tqdm

from scipy import optimize       # to compare
# Out:
# /home/alice/Documents/ramax_vacation/venv/lib/python3.7/site-packages/pandas/compat/__init__.py:97: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
import pickle 

with open('possible_vacation.pickle', 'rb') as f:
    possible_vacation = pickle.load(f)

with open('req_work.pickle', 'rb') as f:
    req_work = pickle.load(f)
    
with open('excel_dict.pickle', 'rb') as f:
    excel_dict = pickle.load(f)

with open('qs.pickle', 'rb') as f:
    qs = pickle.load(f)

# %%
def annealing(random_start,
              cost_function,
              random_neighbour,
              acceptance,
              temperature,
              args,
              maxsteps=1000,
              debug=True
             ):
    state = random_start(*args)
    cost = cost_function(state)
    states, costs = [state], [cost]
    for step in range(maxsteps):
        fraction = step / float(maxsteps)
        T = temperature(fraction)
        new_state = random_neighbour(*args)  # fraction
        new_cost = cost_function(new_state)
#         if debug: print("Step #{:>2}/{:>2} : T = {:>4.3g}, state = {:>4.3g}, cost = {:>4.3g}, new_state = {:>4.3g}, new_cost = {:>4.3g} ...".format(step, maxsteps, T, state, cost, new_state, new_cost))
        if debug: print("Step #{:>2}/{:>2} : T = {:>4.3g} cost = {:>4.3g} new_cost = {:>4.3g} ...".format(step, maxsteps, T, cost, new_cost))          
        if acceptance_probability(cost, new_cost, T) > rn.random():
            state, cost = new_state, new_cost
            states.append(state)
            costs.append(cost)
    return state, cost_function(state), states, costs

# %%
def get_random_vac(max_fly_person, max_fly_month):
    return np.random.randint(36, min(max_fly_person, max_fly_month))


def random_matrix(df):
    state = np.zeros((df.shape[0], 12), dtype=int)
    max_fly_by_month = get_max_fly_by_month()
    aval_hours_by_month = get_D(df, by_month=True)

    for month in range(12):
        i = 0
        while aval_hours_by_month[month] > 0:
            i += 1
            if state.shape[0] - i < 0:
                break
            rand_i = np.random.randint(0, state.shape[0])

            _vac = get_random_vac(
                max_fly_person=df['Max Fly'].iloc[rand_i],
                max_fly_month=max_fly_by_month[month]
            )

            if state[rand_i][month] > 0:
                continue

            # Если уже использовали больше чем нужно отпуск
            if state[rand_i].sum() + _vac > max(df['Max Fly'].iloc[rand_i] * 2, 184):
                continue

            # Если у нас на расстоянии 2 уже есть отпуск
            if month < 11:
                if state[rand_i][month + 1] > 0 or state[rand_i][month - 1] > 0:
                    continue
            else:
                if state[rand_i][0] > 0 or state[rand_i][10] > 0:
                    continue

            # Если число доступных часов больше
            if aval_hours_by_month[month] >= _vac:
                aval_hours_by_month[month] -= _vac
                state[rand_i, month] = _vac

            # Если число доступных часов меньше, то переносим отпуск на след месяц
            else:
                delta = _vac - aval_hours_by_month[month]
                state[rand_i, month] = aval_hours_by_month[month]
                aval_hours_by_month[month] = 0

                if month < 11:
                    state[rand_i, month + 1] += delta
                    aval_hours_by_month[month + 1] -= delta
                else:
                    state[rand_i, 0] += delta
                    aval_hours_by_month[0] -= delta
                break
    return state

# %%
a = random_matrix(qs['Q9'])

# %%
# сделано
display(pd.Series(a.sum(axis=0)))
# Out:
# 0      751
# 1     2677
# 2     1270
# 3     1768
# 4     2009
# 5      852
# 6      722
# 7      719
# 8      831
# 9     1247
# 10     590
# 11     684
# dtype: int64

# %%
# надо
possible_vacation.loc['Q9', :]
# Out:
# 1      751.0
# 2     2913.0
# 3     1270.0
# 4     1768.0
# 5     2009.0
# 6      852.0
# 7      722.0
# 8      719.0
# 9      831.0
# 10    1766.0
# 11    1108.0
# 12    1114.0
# Name: Q9, dtype: float64

# %%
def get_max_fly_by_month():
    return excel_dict['months'][2].values

# %%
def get_D_d(vacs):
    return vacs.sum(axis=0)

def get_D(df, q_name, by_month=False):
    if not by_month:
        return possible_vacation.loc[q_name, :].sum()
    else:
        return possible_vacation.loc[q_name, :].values.copy()

def get_S(df):
    return df[[f'RP{i}_score' for i in range(1, 13)]].values.sum().sum()
    
def get_S_d(vacs, df):
    a = df[[f'RP{i}_score' for i in range(1, 13)]].values
    b = vacs.astype(bool).astype(int)
    return np.multiply(a, b).sum().sum()
    
def cost_function(vacs):
    return f(vacs)

# %%
def cost_function(vacs):
    cost = 1 - get_S_d(vacs, df) / get_S(df)
    return cost

# %%
def acceptance_probability(cost, new_cost, temperature):
    if new_cost < cost:
        return 1
    else:
        p = np.exp(- (new_cost - cost) / temperature)
        return p

# %%
def temperature(fraction):
    return max(0.01, min(1, 1 - fraction))

# %%
def output(q):

    l = []

    for vac, person, person_score in zip(state, df['Num'].values, df[[f'RP{i}_score' for i in range(1, 13)]].values):
        for i, (vac_size, score) in enumerate(zip(vac, person_score), 1):
            if vac_size != 0:
                l.append([person, i, vac_size, 1 if score else 0])
    
    _df = pd.DataFrame(data=l, columns=['id', 'month', 'rest_size', 'aplication'])
    _df.to_csv(f'../data/res_v.0.03_{q}.csv')

# %%
for q_name, df in qs.items():
    print(q_name)
    state, c, states, costs = annealing(
        random_matrix,
        cost_function,
        random_matrix,
        acceptance_probability,
        temperature,
        args=[df],
        maxsteps=1000,
        debug=True
    )
# Out:
# Q1
# Step # 0/1000 : T =    1 cost = 0.937 new_cost = 0.951 ...
# Step # 1/1000 : T = 0.999 cost = 0.951 new_cost = 0.954 ...
# Step # 2/1000 : T = 0.998 cost = 0.954 new_cost = 0.941 ...
# Step # 3/1000 : T = 0.997 cost = 0.941 new_cost = 0.948 ...
# Step # 4/1000 : T = 0.996 cost = 0.948 new_cost = 0.937 ...
# Step # 5/1000 : T = 0.995 cost = 0.937 new_cost = 0.939 ...
# Step # 6/1000 : T = 0.994 cost = 0.939 new_cost = 0.938 ...
# Step # 7/1000 : T = 0.993 cost = 0.938 new_cost = 0.931 ...
# Step # 8/1000 : T = 0.992 cost = 0.931 new_cost = 0.94 ...
# Step # 9/1000 : T = 0.991 cost = 0.94 new_cost = 0.946 ...
# Step #10/1000 : T = 0.99 cost = 0.946 new_cost = 0.933 ...
# Step #11/1000 : T = 0.989 cost = 0.933 new_cost = 0.951 ...
# Step #12/1000 : T = 0.988 cost = 0.951 new_cost = 0.942 ...
# Step #13/1000 : T = 0.987 cost = 0.942 new_cost = 0.936 ...
# Step #14/1000 : T = 0.986 cost = 0.936 new_cost = 0.936 ...
# Step #15/1000 : T = 0.985 cost = 0.936 new_cost = 0.951 ...
# Step #16/1000 : T = 0.984 cost = 0.951 new_cost = 0.943 ...
# Step #17/1000 : T = 0.983 cost = 0.943 new_cost = 0.939 ...
# Step #18/1000 : T = 0.982 cost = 0.939 new_cost = 0.942 ...
# Step #19/1000 : T = 0.981 cost = 0.942 new_cost = 0.943 ...
# Step #20/1000 : T = 0.98 cost = 0.943 new_cost = 0.936 ...
# Step #21/1000 : T = 0.979 cost = 0.936 new_cost = 0.955 ...
# Step #22/1000 : T = 0.978 cost = 0.955 new_cost = 0.948 ...
# Step #23/1000 : T = 0.977 cost = 0.948 new_cost = 0.953 ...
# Step #24/1000 : T = 0.976 cost = 0.953 new_cost = 0.932 ...
# Step #25/1000 : T = 0.975 cost = 0.932 new_cost = 0.948 ...
# Step #26/1000 : T = 0.974 cost = 0.948 new_cost = 0.929 ...
# Step #27/1000 : T = 0.973 cost = 0.929 new_cost = 0.94 ...
# Step #28/1000 : T = 0.972 cost = 0.94 new_cost = 0.943 ...
# Step #29/1000 : T = 0.971 cost = 0.943 new_cost = 0.936 ...
# Step #30/1000 : T = 0.97 cost = 0.936 new_cost = 0.933 ...
# Step #31/1000 : T = 0.969 cost = 0.933 new_cost = 0.946 ...
# Step #32/1000 : T = 0.968 cost = 0.946 new_cost = 0.932 ...
# Step #33/1000 : T = 0.967 cost = 0.932 new_cost = 0.938 ...
# Step #34/1000 : T = 0.966 cost = 0.938 new_cost = 0.944 ...
# Step #35/1000 : T = 0.965 cost = 0.944 new_cost = 0.945 ...
# Step #36/1000 : T = 0.964 cost = 0.945 new_cost = 0.933 ...
# Step #37/1000 : T = 0.963 cost = 0.933 new_cost = 0.927 ...
# Step #38/1000 : T = 0.962 cost = 0.927 new_cost = 0.94 ...
# Step #39/1000 : T = 0.961 cost = 0.94 new_cost = 0.95 ...
# Step #40/1000 : T = 0.96 cost = 0.95 new_cost = 0.925 ...
# Step #41/1000 : T = 0.959 cost = 0.925 new_cost = 0.939 ...
# Step #42/1000 : T = 0.958 cost = 0.939 new_cost = 0.947 ...
# Step #43/1000 : T = 0.957 cost = 0.947 new_cost = 0.932 ...
# Step #44/1000 : T = 0.956 cost = 0.932 new_cost = 0.951 ...
# Step #45/1000 : T = 0.955 cost = 0.951 new_cost = 0.941 ...
# Step #46/1000 : T = 0.954 cost = 0.941 new_cost = 0.947 ...
# Step #47/1000 : T = 0.953 cost = 0.947 new_cost = 0.941 ...
# Step #48/1000 : T = 0.952 cost = 0.941 new_cost = 0.942 ...
# Step #49/1000 : T = 0.951 cost = 0.942 new_cost = 0.943 ...
# Step #50/1000 : T = 0.95 cost = 0.943 new_cost = 0.94 ...
# Step #51/1000 : T = 0.949 cost = 0.94 new_cost = 0.939 ...
# Step #52/1000 : T = 0.948 cost = 0.939 new_cost = 0.95 ...
# Step #53/1000 : T = 0.947 cost = 0.95 new_cost = 0.932 ...
# Step #54/1000 : T = 0.946 cost = 0.932 new_cost = 0.946 ...
# Step #55/1000 : T = 0.945 cost = 0.946 new_cost = 0.943 ...
# Step #56/1000 : T = 0.944 cost = 0.943 new_cost = 0.938 ...
# Step #57/1000 : T = 0.943 cost = 0.938 new_cost = 0.945 ...
# Step #58/1000 : T = 0.942 cost = 0.945 new_cost = 0.952 ...
# Step #59/1000 : T = 0.941 cost = 0.952 new_cost = 0.934 ...
# Step #60/1000 : T = 0.94 cost = 0.934 new_cost = 0.949 ...
# Step #61/1000 : T = 0.939 cost = 0.949 new_cost = 0.947 ...
# Step #62/1000 : T = 0.938 cost = 0.947 new_cost = 0.959 ...
# Step #63/1000 : T = 0.937 cost = 0.959 new_cost = 0.944 ...
# Step #64/1000 : T = 0.936 cost = 0.944 new_cost = 0.945 ...
# Step #65/1000 : T = 0.935 cost = 0.945 new_cost = 0.935 ...
# Step #66/1000 : T = 0.934 cost = 0.935 new_cost = 0.936 ...
# Step #67/1000 : T = 0.933 cost = 0.936 new_cost = 0.942 ...
# Step #68/1000 : T = 0.932 cost = 0.942 new_cost = 0.926 ...
# Step #69/1000 : T = 0.931 cost = 0.926 new_cost = 0.939 ...
# Step #70/1000 : T = 0.93 cost = 0.939 new_cost = 0.934 ...
# Step #71/1000 : T = 0.929 cost = 0.934 new_cost = 0.942 ...
# Step #72/1000 : T = 0.928 cost = 0.942 new_cost = 0.926 ...
# Step #73/1000 : T = 0.927 cost = 0.926 new_cost = 0.931 ...
# Step #74/1000 : T = 0.926 cost = 0.931 new_cost = 0.946 ...
# Step #75/1000 : T = 0.925 cost = 0.946 new_cost = 0.942 ...
# Step #76/1000 : T = 0.924 cost = 0.942 new_cost = 0.948 ...
# Step #77/1000 : T = 0.923 cost = 0.948 new_cost = 0.942 ...
# Step #78/1000 : T = 0.922 cost = 0.942 new_cost = 0.951 ...
# Step #79/1000 : T = 0.921 cost = 0.951 new_cost = 0.929 ...
# Step #80/1000 : T = 0.92 cost = 0.929 new_cost = 0.932 ...
# Step #81/1000 : T = 0.919 cost = 0.932 new_cost = 0.945 ...
# Step #82/1000 : T = 0.918 cost = 0.945 new_cost = 0.957 ...
# Step #83/1000 : T = 0.917 cost = 0.957 new_cost = 0.943 ...
# Step #84/1000 : T = 0.916 cost = 0.943 new_cost = 0.94 ...
# Step #85/1000 : T = 0.915 cost = 0.94 new_cost = 0.932 ...
# Step #86/1000 : T = 0.914 cost = 0.932 new_cost = 0.946 ...
# Step #87/1000 : T = 0.913 cost = 0.946 new_cost = 0.93 ...
# Step #88/1000 : T = 0.912 cost = 0.93 new_cost = 0.946 ...
# Step #89/1000 : T = 0.911 cost = 0.946 new_cost = 0.958 ...
# Step #90/1000 : T = 0.91 cost = 0.958 new_cost = 0.938 ...
# Step #91/1000 : T = 0.909 cost = 0.938 new_cost = 0.945 ...
# Step #92/1000 : T = 0.908 cost = 0.945 new_cost = 0.93 ...
# Step #93/1000 : T = 0.907 cost = 0.93 new_cost = 0.943 ...
# Step #94/1000 : T = 0.906 cost = 0.943 new_cost = 0.933 ...
# Step #95/1000 : T = 0.905 cost = 0.933 new_cost = 0.943 ...
# Step #96/1000 : T = 0.904 cost = 0.943 new_cost = 0.947 ...
# Step #97/1000 : T = 0.903 cost = 0.947 new_cost = 0.932 ...
# Step #98/1000 : T = 0.902 cost = 0.932 new_cost = 0.941 ...
# Step #99/1000 : T = 0.901 cost = 0.941 new_cost = 0.932 ...
# Step #100/1000 : T =  0.9 cost = 0.932 new_cost = 0.932 ...
# Step #101/1000 : T = 0.899 cost = 0.932 new_cost = 0.929 ...
# Step #102/1000 : T = 0.898 cost = 0.929 new_cost = 0.942 ...
# Step #103/1000 : T = 0.897 cost = 0.942 new_cost = 0.944 ...
# Step #104/1000 : T = 0.896 cost = 0.944 new_cost = 0.932 ...
# Step #105/1000 : T = 0.895 cost = 0.932 new_cost = 0.934 ...
# Step #106/1000 : T = 0.894 cost = 0.934 new_cost = 0.95 ...
# Step #107/1000 : T = 0.893 cost = 0.95 new_cost = 0.938 ...
# Step #108/1000 : T = 0.892 cost = 0.938 new_cost = 0.931 ...
# Step #109/1000 : T = 0.891 cost = 0.931 new_cost = 0.94 ...
# Step #110/1000 : T = 0.89 cost = 0.94 new_cost = 0.949 ...
# Step #111/1000 : T = 0.889 cost = 0.949 new_cost = 0.935 ...
# Step #112/1000 : T = 0.888 cost = 0.935 new_cost = 0.945 ...
# Step #113/1000 : T = 0.887 cost = 0.945 new_cost = 0.933 ...
# Step #114/1000 : T = 0.886 cost = 0.933 new_cost = 0.945 ...
# Step #115/1000 : T = 0.885 cost = 0.945 new_cost = 0.949 ...
# Step #116/1000 : T = 0.884 cost = 0.949 new_cost = 0.942 ...
# Step #117/1000 : T = 0.883 cost = 0.942 new_cost = 0.945 ...
# Step #118/1000 : T = 0.882 cost = 0.945 new_cost = 0.947 ...
# Step #119/1000 : T = 0.881 cost = 0.947 new_cost = 0.949 ...
# Step #120/1000 : T = 0.88 cost = 0.949 new_cost = 0.947 ...
# Step #121/1000 : T = 0.879 cost = 0.947 new_cost = 0.947 ...
# Step #122/1000 : T = 0.878 cost = 0.947 new_cost = 0.957 ...
# Step #123/1000 : T = 0.877 cost = 0.957 new_cost = 0.948 ...
# Step #124/1000 : T = 0.876 cost = 0.948 new_cost = 0.948 ...
# Step #125/1000 : T = 0.875 cost = 0.948 new_cost = 0.948 ...
# Step #126/1000 : T = 0.874 cost = 0.948 new_cost = 0.939 ...
# Step #127/1000 : T = 0.873 cost = 0.939 new_cost = 0.926 ...
# Step #128/1000 : T = 0.872 cost = 0.926 new_cost = 0.947 ...
# Step #129/1000 : T = 0.871 cost = 0.947 new_cost = 0.938 ...
# Step #130/1000 : T = 0.87 cost = 0.938 new_cost = 0.943 ...
# Step #131/1000 : T = 0.869 cost = 0.943 new_cost = 0.929 ...
# Step #132/1000 : T = 0.868 cost = 0.929 new_cost = 0.936 ...
# Step #133/1000 : T = 0.867 cost = 0.936 new_cost = 0.933 ...
# Step #134/1000 : T = 0.866 cost = 0.933 new_cost = 0.931 ...
# Step #135/1000 : T = 0.865 cost = 0.931 new_cost = 0.941 ...
# Step #136/1000 : T = 0.864 cost = 0.941 new_cost = 0.942 ...
# Step #137/1000 : T = 0.863 cost = 0.942 new_cost = 0.939 ...
# Step #138/1000 : T = 0.862 cost = 0.939 new_cost = 0.946 ...
# Step #139/1000 : T = 0.861 cost = 0.946 new_cost = 0.942 ...
# Step #140/1000 : T = 0.86 cost = 0.942 new_cost = 0.93 ...
# Step #141/1000 : T = 0.859 cost = 0.93 new_cost = 0.941 ...
# Step #142/1000 : T = 0.858 cost = 0.941 new_cost = 0.945 ...
# Step #143/1000 : T = 0.857 cost = 0.945 new_cost = 0.926 ...
# Step #144/1000 : T = 0.856 cost = 0.926 new_cost = 0.938 ...
# Step #145/1000 : T = 0.855 cost = 0.938 new_cost = 0.948 ...
# Step #146/1000 : T = 0.854 cost = 0.948 new_cost = 0.939 ...
# Step #147/1000 : T = 0.853 cost = 0.939 new_cost = 0.942 ...
# Step #148/1000 : T = 0.852 cost = 0.942 new_cost = 0.943 ...
# Step #149/1000 : T = 0.851 cost = 0.943 new_cost = 0.942 ...
# Step #150/1000 : T = 0.85 cost = 0.942 new_cost = 0.931 ...
# Step #151/1000 : T = 0.849 cost = 0.931 new_cost = 0.935 ...
# Step #152/1000 : T = 0.848 cost = 0.935 new_cost = 0.952 ...
# Step #153/1000 : T = 0.847 cost = 0.952 new_cost = 0.942 ...
# Step #154/1000 : T = 0.846 cost = 0.942 new_cost = 0.957 ...
# Step #155/1000 : T = 0.845 cost = 0.957 new_cost = 0.932 ...
# Step #156/1000 : T = 0.844 cost = 0.932 new_cost = 0.932 ...
# Step #157/1000 : T = 0.843 cost = 0.932 new_cost = 0.948 ...
# Step #158/1000 : T = 0.842 cost = 0.948 new_cost = 0.945 ...
# Step #159/1000 : T = 0.841 cost = 0.945 new_cost = 0.932 ...
# Step #160/1000 : T = 0.84 cost = 0.932 new_cost = 0.954 ...
# Step #161/1000 : T = 0.839 cost = 0.954 new_cost = 0.943 ...
# Step #162/1000 : T = 0.838 cost = 0.943 new_cost = 0.926 ...
# Step #163/1000 : T = 0.837 cost = 0.926 new_cost = 0.928 ...
# Step #164/1000 : T = 0.836 cost = 0.928 new_cost = 0.946 ...
# Step #165/1000 : T = 0.835 cost = 0.946 new_cost = 0.947 ...
# Step #166/1000 : T = 0.834 cost = 0.947 new_cost = 0.939 ...
# Step #167/1000 : T = 0.833 cost = 0.939 new_cost = 0.943 ...
# Step #168/1000 : T = 0.832 cost = 0.943 new_cost = 0.926 ...
# Step #169/1000 : T = 0.831 cost = 0.926 new_cost = 0.944 ...
# Step #170/1000 : T = 0.83 cost = 0.944 new_cost = 0.948 ...
# Step #171/1000 : T = 0.829 cost = 0.948 new_cost = 0.933 ...
# Step #172/1000 : T = 0.828 cost = 0.933 new_cost = 0.949 ...
# Step #173/1000 : T = 0.827 cost = 0.933 new_cost = 0.939 ...
# Step #174/1000 : T = 0.826 cost = 0.939 new_cost = 0.945 ...
# Step #175/1000 : T = 0.825 cost = 0.945 new_cost = 0.934 ...
# Step #176/1000 : T = 0.824 cost = 0.934 new_cost = 0.951 ...
# Step #177/1000 : T = 0.823 cost = 0.951 new_cost = 0.917 ...
# Step #178/1000 : T = 0.822 cost = 0.917 new_cost = 0.935 ...
# Step #179/1000 : T = 0.821 cost = 0.935 new_cost = 0.952 ...
# Step #180/1000 : T = 0.82 cost = 0.952 new_cost = 0.942 ...
# Step #181/1000 : T = 0.819 cost = 0.942 new_cost = 0.941 ...
# Step #182/1000 : T = 0.818 cost = 0.941 new_cost = 0.944 ...
# Step #183/1000 : T = 0.817 cost = 0.944 new_cost = 0.939 ...
# Step #184/1000 : T = 0.816 cost = 0.939 new_cost = 0.943 ...
# Step #185/1000 : T = 0.815 cost = 0.943 new_cost = 0.944 ...
# Step #186/1000 : T = 0.814 cost = 0.944 new_cost = 0.939 ...
# Step #187/1000 : T = 0.813 cost = 0.939 new_cost = 0.944 ...
# Step #188/1000 : T = 0.812 cost = 0.944 new_cost = 0.926 ...
# Step #189/1000 : T = 0.811 cost = 0.926 new_cost = 0.935 ...
# Step #190/1000 : T = 0.81 cost = 0.935 new_cost = 0.943 ...
# Step #191/1000 : T = 0.809 cost = 0.943 new_cost = 0.942 ...
# Step #192/1000 : T = 0.808 cost = 0.942 new_cost = 0.946 ...
# Step #193/1000 : T = 0.807 cost = 0.946 new_cost = 0.934 ...
# Step #194/1000 : T = 0.806 cost = 0.934 new_cost = 0.94 ...
# Step #195/1000 : T = 0.805 cost = 0.94 new_cost = 0.933 ...
# Step #196/1000 : T = 0.804 cost = 0.933 new_cost = 0.935 ...
# Step #197/1000 : T = 0.803 cost = 0.935 new_cost = 0.958 ...
# Step #198/1000 : T = 0.802 cost = 0.958 new_cost = 0.939 ...
# Step #199/1000 : T = 0.801 cost = 0.939 new_cost = 0.951 ...
# Step #200/1000 : T =  0.8 cost = 0.939 new_cost = 0.933 ...
# Step #201/1000 : T = 0.799 cost = 0.933 new_cost = 0.935 ...
# Step #202/1000 : T = 0.798 cost = 0.935 new_cost = 0.95 ...
# Step #203/1000 : T = 0.797 cost = 0.95 new_cost = 0.932 ...
# Step #204/1000 : T = 0.796 cost = 0.932 new_cost = 0.941 ...
# Step #205/1000 : T = 0.795 cost = 0.941 new_cost = 0.943 ...
# Step #206/1000 : T = 0.794 cost = 0.943 new_cost = 0.926 ...
# Step #207/1000 : T = 0.793 cost = 0.926 new_cost = 0.951 ...
# Step #208/1000 : T = 0.792 cost = 0.951 new_cost = 0.939 ...
# Step #209/1000 : T = 0.791 cost = 0.939 new_cost = 0.921 ...
# Step #210/1000 : T = 0.79 cost = 0.921 new_cost = 0.951 ...
# Step #211/1000 : T = 0.789 cost = 0.951 new_cost = 0.919 ...
# Step #212/1000 : T = 0.788 cost = 0.919 new_cost = 0.936 ...
# Step #213/1000 : T = 0.787 cost = 0.936 new_cost = 0.932 ...
# Step #214/1000 : T = 0.786 cost = 0.932 new_cost = 0.94 ...
# Step #215/1000 : T = 0.785 cost = 0.94 new_cost = 0.936 ...
# Step #216/1000 : T = 0.784 cost = 0.936 new_cost = 0.949 ...
# Step #217/1000 : T = 0.783 cost = 0.949 new_cost = 0.932 ...
# Step #218/1000 : T = 0.782 cost = 0.932 new_cost = 0.951 ...
# Step #219/1000 : T = 0.781 cost = 0.951 new_cost = 0.933 ...
# Step #220/1000 : T = 0.78 cost = 0.933 new_cost = 0.936 ...
# Step #221/1000 : T = 0.779 cost = 0.936 new_cost = 0.939 ...
# Step #222/1000 : T = 0.778 cost = 0.939 new_cost = 0.933 ...
# Step #223/1000 : T = 0.777 cost = 0.933 new_cost = 0.954 ...
# Step #224/1000 : T = 0.776 cost = 0.954 new_cost = 0.948 ...
# Step #225/1000 : T = 0.775 cost = 0.948 new_cost = 0.947 ...
# Step #226/1000 : T = 0.774 cost = 0.947 new_cost = 0.929 ...
# Step #227/1000 : T = 0.773 cost = 0.929 new_cost = 0.933 ...
# Step #228/1000 : T = 0.772 cost = 0.933 new_cost = 0.945 ...
# Step #229/1000 : T = 0.771 cost = 0.945 new_cost = 0.947 ...
# Step #230/1000 : T = 0.77 cost = 0.947 new_cost = 0.943 ...
# Step #231/1000 : T = 0.769 cost = 0.943 new_cost = 0.953 ...
# Step #232/1000 : T = 0.768 cost = 0.953 new_cost = 0.953 ...
# Step #233/1000 : T = 0.767 cost = 0.953 new_cost = 0.942 ...
# Step #234/1000 : T = 0.766 cost = 0.942 new_cost = 0.952 ...
# Step #235/1000 : T = 0.765 cost = 0.952 new_cost = 0.953 ...
# Step #236/1000 : T = 0.764 cost = 0.953 new_cost = 0.939 ...
# Step #237/1000 : T = 0.763 cost = 0.939 new_cost = 0.942 ...
# Step #238/1000 : T = 0.762 cost = 0.942 new_cost = 0.936 ...
# Step #239/1000 : T = 0.761 cost = 0.936 new_cost = 0.926 ...
# Step #240/1000 : T = 0.76 cost = 0.926 new_cost = 0.938 ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-437137eaad35> in <module>
#       9         args=[df],
#      10         maxsteps=1000,
# ---> 11         debug=True
#      12     )
#
# <ipython-input-61-149a021fb576> in annealing(random_start, cost_function, random_neighbour, acceptance, temperature, args, maxsteps, debug)
#      14         fraction = step / float(maxsteps)
#      15         T = temperature(fraction)
# ---> 16         new_state = random_neighbour(*args)  # fraction
#      17         new_cost = cost_function(new_state)
#      18 #         if debug: print("Step #{:>2}/{:>2} : T = {:>4.3g}, state = {:>4.3g}, cost = {:>4.3g}, new_state = {:>4.3g}, new_cost = {:>4.3g} ...".format(step, maxsteps, T, state, cost, new_state, new_cost))
#
# <ipython-input-50-06d2d3b37818> in random_matrix(df)
#      21             )
#      22
# ---> 23             if state[rand_i][month] > 0:
#      24                 continue
#      25
#
# KeyboardInterrupt:

# %% [markdown]
# ### Output
